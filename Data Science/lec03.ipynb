# %%
print('hello') #textual literals
# Out:
# hello

# %%
number = eval(input("Enter an expression:"))
number
# Out:
# Enter an expression: 33+24
# 57

# %%
float(5)
# Out:
# 5.0

# %%
int(5.64687)
# Out:
# 5

# %%
str(55.2210)
# Out:
# '55.221'

# %%
str(10.00)
# Out:
# '10.0'

# %%
str(10.0)
# Out:
# '10.0'

# %%
str(10.06)
# Out:
# '10.06'

# %%
str(10.654)
# Out:
# '10.654'

# %%
_var = 3
_var
# Out:
# 3

# %%
user_input = eval(input("Enter any expression:"))
user_input
# Out:
# Enter any expression: 8+9.7+3
# 20.7

# %%
name = "shawaiz"
age = 20
str(age)
# Out:
# '20'

# %%
float(age)
# Out:
# 20.0

# %%
x,y,z = 5,8.4,900
print(x) # numerical literals
print(y)
print(z)
# Out:
# 5
# 8.4
# 900

# %%
isRunning = False
isRunning
# Out:
# False

# %%
x = abs(-92)
x
# Out:
# 92

# %%
model = int("57")
model
# Out:
# 57

# %%
model = 2 + 3.2 # implicity type conversion
model
# Out:
# 5.2

# %%
height = 8 // 2 + 2.6
height
# Out:
# 6.6

# %%
"""
This is a multi-line comment.
Using triple quotes (single or double).
"""
# Out:
# '\nThis is a multi-line comment.\nUsing triple quotes (single or double).\n'

# %%
animals = ["zeebra", "deer", "lion", "cheeta", "elephant", "rhino", "leopard", "horse"]
animals
# Out:
# ['zeebra', 'deer', 'lion', 'cheeta', 'elephant', 'rhino', 'leopard', 'horse']

# %%
for i in animals:
    print(i)
# Out:
# zeebra
# deer
# lion
# cheeta
# elephant
# rhino
# leopard
# horse

# %%
print??
# Out:
# Signature: print(*args, sep=' ', end='\n', file=None, flush=False)
# Docstring:
# Prints the values to a stream, or to sys.stdout by default.
#
# sep
#   string inserted between values, default a space.
# end
#   string appended after the last value, default a newline.
# file
#   a file-like object (stream); defaults to the current sys.stdout.
# flush
#   whether to forcibly flush the stream.
# Type:      builtin_function_or_method

# %%
print?
# Out:
# Signature: print(*args, sep=' ', end='\n', file=None, flush=False)
# Docstring:
# Prints the values to a stream, or to sys.stdout by default.
#
# sep
#   string inserted between values, default a space.
# end
#   string appended after the last value, default a newline.
# file
#   a file-like object (stream); defaults to the current sys.stdout.
# flush
#   whether to forcibly flush the stream.
# Type:      builtin_function_or_method

# %%
for i in animals:
    print(i, end=" || ")
# Out:
# zeebra || deer || lion || cheeta || elephant || rhino || leopard || horse ||

# %%
for index, item in enumerate(animals):
    print(f"{index+1}: {item}") # Using f-string
# Out:
# 1: zeebra
# 2: deer
# 3: lion
# 4: cheeta
# 5: elephant
# 6: rhino
# 7: leopard
# 8: horse

# %%
help("for")
# Out:
# The "for" statement
# *******************
#
# The "for" statement is used to iterate over the elements of a sequence
# (such as a string, tuple or list) or other iterable object:
#
#    for_stmt ::= "for" target_list "in" starred_list ":" suite
#                 ["else" ":" suite]
#
# The "starred_list" expression is evaluated once; it should yield an
# *iterable* object.  An *iterator* is created for that iterable. The
# first item provided by the iterator is then assigned to the target
# list using the standard rules for assignments (see Assignment
# statements), and the suite is executed.  This repeats for each item
# provided by the iterator.  When the iterator is exhausted, the suite
# in the "else" clause, if present, is executed, and the loop
# terminates.
#
# A "break" statement executed in the first suite terminates the loop
# without executing the "else" clause’s suite.  A "continue" statement
# executed in the first suite skips the rest of the suite and continues
# ...

# %%
range??
# Out:
# Init signature: range(self, /, *args, **kwargs)
# Docstring:
# range(stop) -> range object
# range(start, stop[, step]) -> range object
#
# Return an object that produces a sequence of integers from start (inclusive)
# to stop (exclusive) by step.  range(i, j) produces i, i+1, i+2, ..., j-1.
# start defaults to 0, and stop is omitted!  range(4) produces 0, 1, 2, 3.
# These are exactly the valid indices for a list of 4 elements.
# When step is given, it specifies the increment (or decrement).
# Type:           type
# Subclasses:

# %%
for i in range(0, 20, 5): # range(start, stop, increment)
    print(i)
# Out:
# 0
# 5
# 10
# 15

# %%
for i in range(20, 0, -5): # range(start, stop, decrement)
    print(i)
# Out:
# 20
# 15
# 10
# 5

# %%
for index in range(len(animals)):
    item = animals[index]
    print(index, ":", item)
   # print(f"{index}: {item}")
# Out:
# 0 : zeebra
# 1 : deer
# 2 : lion
# 3 : cheeta
# 4 : elephant
# 5 : rhino
# 6 : leopard
# 7 : horse

# %%
enumerate??
# Out:
# Init signature: enumerate(iterable, start=0)
# Docstring:
# Return an enumerate object.
#
#   iterable
#     an object supporting iteration
#
# The enumerate object yields pairs containing a count (from start, which
# defaults to zero) and a value yielded by the iterable argument.
#
# enumerate is useful for obtaining an indexed list:
#     (0, seq[0]), (1, seq[1]), (2, seq[2]), ...
# Type:           type
# Subclasses:

# %%
for i in enumerate(animals, start=1):
    print(i)
# Out:
# (1, 'zeebra')
# (2, 'deer')
# (3, 'lion')
# (4, 'cheeta')
# (5, 'elephant')
# (6, 'rhino')
# (7, 'leopard')
# (8, 'horse')

# %%
for index, item in enumerate(animals, start=1):
    print(f"{index}: {item}")
# Out:
# 1: zeebra
# 2: deer
# 3: lion
# 4: cheeta
# 5: elephant
# 6: rhino
# 7: leopard
# 8: horse

# %%
i = 0
while i < len(animals):
    print(f"{i+1}-{animals[i]}", end=", ")
    i += 1
# Out:
# 1-zeebra, 2-deer, 3-lion, 4-cheeta, 5-elephant, 6-rhino, 7-leopard, 8-horse,

# %%
def func():
    print("hello")

func()
# Out:
# hello

# %%
def func(*argv): # for multiple arguments
    for i in argv:
        print(i)

func("animals", 5, 6.387, 50+65, 0)
# Out:
# animals
# 5
# 6.387
# 115
# 0

# %%
"""
Reusable programs are usually created by typing definitions into a separate file
called a module or script.
▪ This file is saved on disk so that it can be used over and over again

▪ A Python module file is just a text file with a .py extension, which can be created using
any program for editing text (e.g., notepad or vim)

▪ Namespace Isolation: Each module defines its own namespace, preventing naming conflicts between 
identifiers (variables, functions, classes) in different parts of a program.

▪ Built-in Modules: math for mathematical operations, random for generating random numbers, 
and os for interacting with the operating system.


path/module.py
----------------------------------------------------------
def printMsg(msg):
print (msg*2)
----------------------------------------------------------

Notebook or any other python program
----------------------------------------------------------
import sys
sys.path.append(‘path to folder where module.py exists’)
import module as myf

myf.printMsg(“hello”)
----------------------------------------------------------

"""

# %%
# !pip install jupyturtle

# %%
import jupyturtle as jt
jt.make_turtle()
jt.forward(100)
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75 250,75" />'
#
# <g transform="rotate(-90.0,250.0,75.0) translate(250.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>
